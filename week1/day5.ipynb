# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/2024/08/06/outsmart/',
#  'https://edwarddonner.com/2024/08/06/outsmart/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/2024/08/06/outsmart/
# https://edwarddonner.com/2024/08/06/outsmart/
# https://edwarddonner.com/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/posts',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/hexgrad/Kokoro-82M',
#  '/openbmb/MiniCPM-o-2_6',
#  '/microsoft/phi-4',
#  '/MiniMaxAI/MiniMax-Text-01',
#  '/NovaSky-AI/Sky-T1-32B-Preview',
#  '/models',
#  '/spaces/hexgrad/Kokoro-TTS',
#  '/spaces/JeffreyXiang/TRELLIS',
#  '/spaces/FaceOnLive/Face-Search-Online',
#  '/spaces/lllyasviel/iclight-v2',
#  '/spaces/Kwai-Kolors/Kolors-Virtual-Try-On',
#  '/spaces',
#  '/datasets/fka/awesome-chatgpt-prompts',
#  '/datasets/NovaSky-AI/Sky-T1_data_17k',
#  '/datasets/HumanLLMs/Human-Like-DPO-Dataset',
#  '/datasets/DAMO-NLP-SG/multimodal_textbook',
#  '/datasets/FreedomIntelligence/medical-o1-reasoning-SFT',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/peft',
#  '/docs/transformers.js',
#  '/docs/timm',
#  '/docs/trl',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/tasks',
#  'https://ui.endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'discuss forum', 'url': 'https://discuss.huggingface.co'},
#   {'type': 'GitHub page', 'url': 'https://github.com/huggingface'},
#   {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'},
#   {'type': 'LinkedIn page',
#    'url': 'https://www.linkedin.com/company/huggingface/'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Trending on
# this week
# Models
# hexgrad/Kokoro-82M
# Updated
# 1 day ago
# •
# 25k
# •
# 1.99k
# openbmb/MiniCPM-o-2_6
# Updated
# 16 minutes ago
# •
# 15k
# •
# 605
# microsoft/phi-4
# Updated
# 11 days ago
# •
# 124k
# •
# 1.44k
# MiniMaxAI/MiniMax-Text-01
# Updated
# 2 days ago
# •
# 2.38k
# •
# 402
# NovaSky-AI/Sky-T1-32B-Preview
# Updated
# 6 days ago
# •
# 7.51k
# •
# 474
# Browse 400k+ models
# Spaces
# Running
# on
# Zero
# 1.15k
# ❤️
# Kokoro TTS
# Now in 5 languages!
# Running
# on
# Zero
# 3.12k
# 🏢
# TRELLIS
# Scalable and Versatile 3D Generation from images
# Running
# 712
# 🔍😊
# Search Your Face Online
# Track your online presence with reverse face search
# Running
# on
# Zero
# 1.71k
# 📈
# IC Light V2
# Running
# on
# CPU Upgrade
# 6.84k
# 👕
# Kolors Virtual Try-On
# Browse 150k+ applications
# Datasets
# fka/awesome-chatgpt-prompts
# Updated
# 14 days ago
# •
# 5.96k
# •
# 6.95k
# NovaSky-AI/Sky-T1_data_17k
# Updated
# 5 days ago
# •
# 1.74k
# •
# 121
# HumanLLMs/Human-Like-DPO-Dataset
# Updated
# 7 days ago
# •
# 914
# •
# 110
# DAMO-NLP-SG/multimodal_textbook
# Updated
# 8 days ago
# •
# 9.57k
# •
# 115
# FreedomIntelligence/medical-o1-reasoning-SFT
# Updated
# 6 days ago
# •
# 912
# •
# 77
# Browse 100k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 378 models
# •
# 1.92k followers
# AI at Meta
# Enterprise
# company
# •
# 2.06k models
# •
# 4.17k followers
# Amazon Web Services
# company
# •
# 20 models
# •
# 2.54k followers
# Google
# company
# •
# 913 models
# •
# 6.63k followers
# Intel
# company
# •
# 218 models
# •
# 2.15k followers
# Microsoft
# company
# •
# 353 models
# •
# 7.46k followers
# Grammarly
# company
# •
# 10 models
# •
# 112 followers
# Writer
# Enterprise
# company
# •
# 18 models
# •
# 198 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 137,750
# State-of-the-art ML for Pytorch, TensorFlow, and JAX.
# Diffusers
# 27,161
# State-of-the-art diffusion models for image and audio generation in PyTorch.
# Safetensors
# 3,012
# Simple, safe way to store and distribute neural networks weights safely and quickly.
# Hub Python Library
# 2,235
# Client library for the HF Hub: manage repositories from your Python runtime.
# Tokenizers
# 9,266
# Fast tokenizers, optimized for both research and production.
# PEFT
# 17,007
# Parameter efficient finetuning methods for large models.
# Transformers.js
# 12,615
# State-of-the-art Machine Learning for the web. Run Transformers directly in your browser, with no need for a server.
# timm
# 32,928
# State-of-the-art computer vision models, layers, optimizers, training/evaluation, and utilities.
# TRL
# 10,632
# Train transformer language models with reinforcement learning.
# Datasets
# 19,473
# Access and share datasets for computer vision, audio, and NLP tasks.
# Text Generation Inference
# 9,601
# Toolkit to serve Large Language Models.
# Accelerate
# 8,187
# Easily train and use PyTorch models with multi-GPU, TPU, mixed-precision.
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 12,957
# AI & ML interests
# The AI community building the future.
# Recent Activity
# nielsr
# updated
# a dataset
# about 8 hours ago
# huggingface/community-science-merged
# yjernite
# new
# activity
# 2 days ago
# huggingface/policy-docs:
# Reuploaded the file so that it becomes LFS
# evijit
# updated
# a dataset
# 2 days ago
# huggingface/policy-docs
# View all activity
# Team members
# 222
# +188
# +175
# +154
# +144
# +124
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 286k
# •
# 36
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 12.6M
# •
# •
# 600
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 588k
# •
# 161
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# Updated
# Dec 19, 2023
# •
# 6.68M
# •
# •
# 672
# spaces
# 23
# Sort:
# 		Recently updated
# pinned
# Running
# 59
# 📈
# Number Tokenization Blog
# Running
# 511
# 😻
# Open Source Ai Year In Review 2024
# What happened in open-source AI this year, and what’s next?
# Running
# 46
# 🔋
# Inference Playground
# Running
# 206
# ⚡
# paper-central
# Running
# on
# TPU v5e
# 8
# 💬
# Keras Chatbot Battle
# Running
# 102
# ⚡
# Modelcard Creator
# Expand 23
# 							spaces
# models
# 18
# Sort:
# 		Recently updated
# huggingface/test-gating-group-2
# Updated
# Dec 17, 2024
# huggingface/test-gating-group-1
# Updated
# Dec 17, 2024
# huggingface/timesfm-tourism-monthly
# Updated
# Dec 9, 2024
# •
# 10
# •
# 1
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 1.1k
# •
# 54
# huggingface/falcon-40b-gptq
# Text Generation
# •
# Updated
# Jun 14, 2023
# •
# 22
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 1.53k
# •
# 9
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# Updated
# Mar 22, 2023
# •
# 311
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 1.44k
# •
# 5
# huggingface/time-series-transformer-tourism-monthly
# Updated
# Feb 23, 2023
# •
# 1.68k
# •
# 18
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 73
# •
# 3
# Expand 18
# 							models
# datasets
# 32
# Sort:
# 		Recently updated
# huggingface/community-science-merged
# Viewer
# •
# Updated
# about 8 hours ago
# •
# 5.26k
# •
# 297
# •
# 3
# huggingface/policy-docs
# Updated
# 2 days ago
# •
# 1.52k
# •
# 6
# huggingface/documentation-images
# Viewer
# •
# Updated
# 2 days ago
# •
# 50
# •
# 2.28M
# •
# 47
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# 6 days ago
# •
# 64
# •
# 399
# •
# 5
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# 6 days ago
# •
# 1.54k
# •
# 329
# •
# 15
# huggingface/paper-central-data
# Viewer
# •
# Updated
# 15 days ago
# •
# 124k
# •
# 522
# •
# 8
# huggingface/community-science-paper-v2
# Viewer
# •
# Updated
# 28 days ago
# •
# 5.03k
# •
# 136
# •
# 7
# huggingface/my-distiset-3f5a230e
# Updated
# Nov 21, 2024
# •
# 18
# huggingface/cookbook-images
# Viewer
# •
# Updated
# Nov 14, 2024
# •
# 1
# •
# 29.4k
# •
# 6
# huggingface/vllm-metadata
# Updated
# Oct 8, 2024
# •
# 12
# Expand 32
# 							datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# blog
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# Timm ❤️ Transformers: Use any timm model with transformers
# By
# ariG23498
# January 16, 2025
# •
# 28
# Community Articles
# view all
# Accelerating LLM Code Generation Through Mask Store Streamlining
# By
# vivien
# •
# 1 day ago
# Topic 23: What is LLM Inference, it's challenges and solutions for it
# By
# Kseniase
# •
# 2 days ago
# •
# 4
# Alpine Agent: An AI Agent to Navigate Your Winter Mountain Adventures
# By
# florentgbelidji
# •
# 2 days ago
# •
# 3
# On-Demand Audio Transcription using Public Infrastructure
# By
# ZennyKenny
# •
# 2 days ago
# Gradio spaces are the perfect agent tools\!
# By
# burtenshaw
# •
# 2 days ago
# •
# 10
# Enhancing AI Teamwork with Tavily Search in KaibanJS
# By
# darielnoel
# •
# 3 days ago
# Unleashing the Symphony of Original Thought: A New Era of Artificial General Intelligence
# By
# fuzzy-mittenz
# •
# 3 days ago
# •
# 1
# Mask is Important for virtual try-on task
# By
# xiaozaa
# •
# 3 days ago
# The Large Language Model Course
# By
# mlabonne
# •
# 3 days ago
# •
# 56
# The Diffusion Principle Understood From The Perspective Of Convolution
# By
# refoundd
# •
# 3 days ago
# •
# 4
# Dria Pythonic Agent Benchmark (DPAB)
# By
# andthattoo
# •
# 4 days ago
# •
# 5
# MiniMax-01 is Now Open-Source: Scaling Lightning Attention for the AI Agent Era
# By
# MiniMax-AI
# •
# 4 days ago
# •
# 36
# Diving into MiniMax01 405B MoE
# By
# eliebak
# •
# 4 days ago
# •
# 17
# LTX-Video LoRA training study (Single image/style training)
# By
# neph1
# •
# 5 days ago
# 🌁#83: GAN is back
# By
# Kseniase
# •
# 6 days ago
# •
# 7
# Building a Real-Time Video Chat with Gemini 2.0, Gradio, and WebRTC 👀👂
# By
# freddyaboulton
# •
# 6 days ago
# •
# 4
# Embodied AI == Unlimited Training Data
# By
# kenhktsui
# •
# 6 days ago
# •
# 2
# Mastering Tensor Dimensions in Transformers
# By
# not-lain
# •
# 7 days ago
# •
# 33
# A Multi-Agent Ecosystem for Autonomous AI
# By
# adityagaharawar
# •
# 7 days ago
# Exploring Hard Negative Mining with NV-Retriever in Korean Financial Text
# By
# Albertmade
# •
# 7 days ago
# •
# 10
# Introducing multi-backends (TRT-LLM, vLLM) support for Text Generation Inference
# By
# mfuntowicz
# January 16, 2025
# •
# 43
# Train 400x faster Static Embedding Models with Sentence Transformers
# By
# tomaarsen
# January 15, 2025
# •
# 105
# Run ComfyUI workflows for free on Spaces
# By
# multimodalart
# January 14, 2024
# •
# 35
# AI Agents Are Here. What Now?
# By
# meg
# January 13, 2025
# •
# 49
# Visual Document Retrieval Goes Multilingual
# By
# marco
# January 10, 2025
# guest
# •
# 58
# CO₂ Emissions and Models Performance: Insights from the Open LLM Leaderboard
# By
# alozowski
# January 9, 2025
# •
# 14
# Introducing smolagents: simple agents that write actions in code.
# By
# m-ric
# December 31, 2024
# •
# 510
# Visualize and understand GPU memory in PyTorch
# By
# qgallouedec
# December 24, 2024
# •
# 162
# Controlling Language Model Generation with NVIDIA's LogitsProcessorZoo
# By
# ariG23498
# December 23, 2024
# •
# 34
# Evaluating Audio Reasoning with Big Bench Audio
# By
# mhillsmith
# December 20, 2024
# guest
# •
# 16
# Finally, a Replacement for BERT: Introducing ModernBERT
# By
# bwarner
# December 19, 2024
# guest
# •
# 489
# Bamba: Inference-Efficient Hybrid Mamba2 Model
# By
# Linsong-C
# December 18, 2024
# guest
# •
# 39
# Welcome the Falcon 3 Family of Open Models!
# By
# FalconLLM
# December 17, 2024
# •
# 116
# Benchmarking Language Model Performance on 5th Gen Xeon at GCP
# By
# MatrixYao
# December 17, 2024
# •
# 3
# Previous
# 1
# 2
# 3
# ...
# 37
# Next
# Community Articles
# view all
# Accelerating LLM Code Generation Through Mask Store Streamlining
# By
# vivien
# •
# 1 day ago
# Topic 23: What is LLM Inference, it's challenges and solutions for it
# By
# Kseniase
# •
# 2 days ago
# •
# 4
# Alpine Agent: An AI Agent to Navigate Your Winter Mountain Adventures
# By
# florentgbelidji
# •
# 2 days ago
# •
# 3
# On-Demand Audio Transcription using Public Infrastructure
# By
# ZennyKenny
# •
# 2 days ago
# Gradio spaces are the perfect agent tools\!
# By
# burtenshaw
# •
# 2 days ago
# •
# 10
# Enhancing AI Teamwork with Tavily Search in KaibanJS
# By
# darielnoel
# •
# 3 days ago
# Unleashing the Symphony of Original Thought: A New Era of Artificial General Intelligence
# By
# fuzzy-mittenz
# •
# 3 days ago
# •
# 1
# Mask is Important for virtual try-on task
# By
# xiaozaa
# •
# 3 days ago
# The Large Language Model Course
# By
# mlabonne
# •
# 3 days ago
# •
# 56
# The Diffusion Principle Understood From The Perspective Of Convolution
# By
# refoundd
# •
# 3 days ago
# •
# 4
# Dria Pythonic Agent Benchmark (DPAB)
# By
# andthattoo
# •
# 4 days ago
# •
# 5
# MiniMax-01 is Now Open-Source: Scaling Lightning Attention for the AI Agent Era
# By
# MiniMax-AI
# •
# 4 days ago
# •
# 36
# Diving into MiniMax01 405B MoE
# By
# eliebak
# •
# 4 days ago
# •
# 17
# LTX-Video LoRA training study (Single image/style training)
# By
# neph1
# •
# 5 days ago
# 🌁#83: GAN is back
# By
# Kseniase
# •
# 6 days ago
# •
# 7
# Building a Real-Time Video Chat with Gemini 2.0, Gradio, and WebRTC 👀👂
# By
# freddyaboulton
# •
# 6 days ago
# •
# 4
# Embodied AI == Unlimited Training Data
# By
# kenhktsui
# •
# 6 days ago
# •
# 2
# Mastering Tensor Dimensions in Transformers
# By
# not-lain
# •
# 7 days ago
# •
# 33
# A Multi-Agent Ecosystem for Autonomous AI
# By
# adityagaharawar
# •
# 7 days ago
# Exploring Hard Negative Mining with NV-Retriever in Korean Financial Text
# By
# Albertmade
# •
# 7 days ago
# •
# 10
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# company page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# View all 490 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We‚Äôre on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Bassem ASSEH
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# See all employees
# Updates
# Hugging Face
# reposted this
# Gradio
# 50,699 followers
# 1d
# Edited
# Report this post
# ‚ö°Ô∏èJUST DROPPED: Create custom AI voices in seconds!
# > Mix multiple voices [üîä:ON]
# > Zero coding needed
# > Intuitive & slick UI with voice sliders
# > Built with Kokoro-82M; blazing fast!
#
# üéØ Kokoro Voice Mixer Studio is perfect for:
# > YouTubers needing unique voiceovers
# > Developers building voice apps
# > Content creators
# > Podcasters
# > Anyone wanting a custom AI voice!
#
# You can access this gradio app on
# Hugging Face
# Spaces:
# https://lnkd.in/gACnsjiS
# ‚Ä¶more
# 213
# 7 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 50,699 followers
# 3d
# Report this post
# üëã Hey all! What upcoming Gradio features you looking most forward to?üòç
# 1Ô∏è‚É£Multipage apps (pressüëç)
# 2Ô∏è‚É£Loading VLM apps from OpenAI API supporting endpoints (pressüëè) or
# 3Ô∏è‚É£Programmatically clearing or updating the ChatInterface values (press‚ù§Ô∏è)
#
# We have these and many other fantastic features in the works for the community. Visit us to stay updated on the progress! üëÄ:
# https://lnkd.in/gah9kD6
# GitHub - gradio-app/gradio: Build and share delightful machine learning apps, all in Python. üåü Star to support our work!
# github.com
# 46
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 50,699 followers
# 3d
# Report this post
# ü§†OuteTTS - multilingual, powerful, supports cloning, comes in two sizes - 500M and 1B.
#
# Play with the official gradio app on ü§óSpaces:
# https://lnkd.in/guSJ3tpu
# Vaibhav Srivastav
# GPU poor @ Hugging Face
# 2mo
# Smol TTS models are here! OuteTTS-0.1-350M - Zero shot voice cloning, built on LLaMa architecture, CC-BY license! üî•
#
# > Pure language modeling approach to TTS
# > Zero-shot voice cloning
# > LLaMa architecture w/ Audio tokens (WavTokenizer)
# > BONUS: Works on-device w/
# llama.cpp
# ‚ö°
#
# Three-step approach to TTS:
#
# > Audio tokenization using WavTokenizer (75 tok per second)
# > CTC forced alignment for¬†word-to-audio token mapping
# > Structured prompt creation w/ transcription, duration, audio tokens
#
# The model is extremely impressive for 350M parameters! Kudos to the¬†
# OuteAI team on such a brilliant feat - I'd love to see this be applied on larger data and smarter backbones like SmolLM ü§ó
# 21
# 1 Comment
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 50,699 followers
# 3d
# Edited
# Report this post
# ü§Ø ü§Ø4 Million context window and commercially permissive
#
# MiniMax-Text-01 with 456 billion params!
#
# To better unlock the long context capabilities of the model, MiniMax-Text-01 adopts a hybrid architecture that combines Lightning Attention, Softmax Attention and Mixture-of-Experts (MoE). A powerful LLM of 456 B parameters, of which 45.9 billion are activated per token!
#
# Model and Chat app present on
# Hugging Face
# ü§ó !
# 432
# 15 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face ü§ó
# 3d
# Edited
# Report this post
# What's up Bangalore? Long time no speak.
# Google Cloud
# and
# Hugging Face
# are organizing an in-person meetup on 25th January on (open) multimodal models.
#
# I am guessing the registrations will be exhausted by tonight. Don't prove me wrong ü§ó
#
# Event page:
# https://lnkd.in/gZSMquym
# Thanks to
# Prashanth
# for making this happen!
# 162
# 8 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face ü§ó
# 4d
# Report this post
# We have been fine-tuning a bunch of video models on Pika effects üß®
#
# I think the results are nice given these were obtained with small & experimental runs with CogVideoX-5B on "Dissolve".
#
# Check out more samples and the model here:
# https://lnkd.in/gu3zvU4n
# Trained with ü§ó Finetrainers by
# Aryan V S
# and yours truly
# https://lnkd.in/gfd2Xfdq
# Time to make video models your own üé∏
# ‚Ä¶more
# 181
# 6 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Florent Daudens
# AI & Journalism @ Hugging Face
# 3d
# Report this post
# AI agents are coming. But who's in control?
# Margaret Mitchell
# , one of the best researchers in AI ethics, makes a critical point about autonomy: fully autonomous systems carry unknowable risks because they operate on computer logic rather than human logic.
#
# The solution? Build systems that support & assist rather than override human decisions.
#
# I highly recommend reading the blog post written by Meg,
# Avijit Ghosh, PhD
# ,
# Dr. Sasha Luccioni
# , and
# Giada Pistilli, PhD
# @
# Hugging Face
# (link in comments). They define different levels of agent autonomy & provide a values-based analysis of risks, benefits, and uses of AI agents to help you make better decisions. You'll find yourself coming back to it throughout 2025.
# ‚Ä¶more
# 71
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Aymeric Roucher
# Building agents @ Hugging Face ü§ó | Polytechnique - Cambridge
# 3d
# Edited
# Report this post
# ùó™ùó≤'ùòÉùó≤ ùó∑ùòÇùòÄùòÅ ùóøùó≤ùóπùó≤ùóÆùòÄùó≤ùó± ùòÄùó∫ùóºùóπùóÆùó¥ùó≤ùóªùòÅùòÄ ùòÉùü≠.ùüØ.ùü¨ üöÄ, and it comes with a major feature: you can now log agent runs using OpenTelemetry to inspect them afterwards! üìä
#
# This interactive format is IMO much easier to inspect big multi-step runs than endless console logs.
#
# The setup is very easy, in a few lines of code.
#
# Find a tutorial here üëâ
# https://lnkd.in/e8ajU8AG
# ‚Ä¶more
# 326
# 10 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# AI datasets @ ü§ó Hugging Face
# 3d
# Edited
# Report this post
# We're thrilled to announce the official
# Hugging Face
# Agents course! This interactive and certified course will guide you through building and deploying your own AI agents.
#
# Enrol Now:
# https://lnkd.in/eUYUzHBS
# TL;DR: Learn to build your own AI agents with our new free and certified course on Hugging Face Learn!
#
# In this course, you will:
#  - Master the fundamentals: Understand how agents perceive, reason, and act in their environment.
#  - Use relevant frameworks: Build agents with LangChain, LlamaIndex, and smolagents.
#  - Explore real-world use cases: See how agents automate tasks, generate code, and more.
#  - Earn a certification: Prove your skills with a hands-on project and benchmark assessment.
# 3,115
# 150 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face ü§ó
# 4d
# Report this post
# We have been fine-tuning a bunch of video models on Pika effects üß®
#
# I think the results are nice given these were obtained with small & experimental runs with CogVideoX-5B on "Dissolve".
#
# Check out more samples and the model here:
# https://lnkd.in/gu3zvU4n
# Trained with ü§ó Finetrainers by
# Aryan V S
# and yours truly
# https://lnkd.in/gfd2Xfdq
# Time to make video models your own üé∏
# ‚Ä¶more
# 181
# 6 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Perplexity
# Software Development
# San Francisco, California
# Generative AI
# Technology, Information and Internet
# Google DeepMind
# Research Services
# London, London
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Cohere
# Software Development
# Toronto, Ontario
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Analyst jobs
# 694,057 open jobs
# Intelligence Specialist jobs
# 7,156 open jobs
# Manager jobs
# 1,880,925 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Director jobs
# 1,220,357 open jobs
# Associate jobs
# 1,091,945 open jobs
# Python Developer jobs
# 46,642 open jobs
# Evangelist jobs
# 5,068 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Quantitative Analyst jobs
# 19,570 open jobs
# Program Manager jobs
# 243,900 open jobs
# Data Science Specialist jobs
# 2,441 open jobs
# Lead Software Engineer jobs
# 68,215 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 7 total rounds
# Last Round
# Series D
# Feb 16, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Intern jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Scientist jobs
# Developer jobs
# Research Intern jobs
# Analyst jobs
# Intelligence Specialist jobs
# Quantitative Analyst jobs
# Technician jobs
# Data Science Specialist jobs
# Project Manager jobs
# Summer Intern jobs
# Manager jobs
# Senior Staff Engineer jobs
# PHD jobs
# Trader jobs
# Researcher jobs
# Data Scientist jobs
# Writer jobs
# Data Analyst jobs
# Product Designer jobs
# Back End Developer jobs
# Spring Intern jobs
# Program Manager jobs
# Technology Officer jobs
# Software Intern jobs
# Security Professional jobs
# Senior Software Engineer jobs
# Python Developer jobs
# Engineering Manager jobs
# Web Developer jobs
# Graduate jobs
# Full Stack Engineer jobs
# Professor jobs
# Head jobs
# Verification Manager jobs
# User Experience Designer jobs
# Recruiter jobs
# Chief Executive Officer jobs
# Associate jobs
# Support Developer jobs
# Senior Firmware Engineer jobs
# Marketing Manager jobs
# Modeling Engineer jobs
# Designer jobs
# Automation Lead jobs
# Options Trader jobs
# Agile Coach jobs
# Research Engineer jobs
# Software Quality Assurance Analyst jobs
# User Experience Manager jobs
# Technical Intern jobs
# Junior Network Engineer jobs
# Information Technology Recruiter jobs
# User Researcher jobs
# Player jobs
# Engineering Project Manager jobs
# Digital Strategist jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# ÿßŸÑÿπÿ±ÿ®Ÿäÿ© (Arabic)
# ‡¶¨‡¶æ‡¶Ç‡¶≤‡¶æ (Bangla)
# ƒåe≈°tina (Czech)
# Dansk (Danish)
# Deutsch (German)
# ŒïŒªŒªŒ∑ŒΩŒπŒ∫Œ¨ (Greek)
# English (English)
# Espa√±ol (Spanish)
# ŸÅÿßÿ±ÿ≥€å (Persian)
# Suomi (Finnish)
# Fran√ßais (French)
# ‡§π‡§ø‡§Ç‡§¶‡•Ä (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# ◊¢◊ë◊®◊ô◊™ (Hebrew)
# Êó•Êú¨Ë™û (Japanese)
# ÌïúÍµ≠Ïñ¥ (Korean)
# ‡§Æ‡§∞‡§æ‡§†‡•Ä (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ‡®™‡©∞‡®ú‡®æ‡®¨‡©Ä (Punjabi)
# Polski (Polish)
# Portugu√™s (Portuguese)
# Rom√¢nƒÉ (Romanian)
# –†—É—Å—Å–∫–∏–π (Russian)
# Svenska (Swedish)
# ‡∞§‡±Ü‡∞≤‡±Å‡∞ó‡±Å (Telugu)
# ‡∏†‡∏≤‡∏©‡∏≤‡πÑ‡∏ó‡∏¢ (Thai)
# Tagalog (Tagalog)
# T√ºrk√ße (Turkish)
# –£–∫—Ä–∞—ó–Ω—Å—å–∫–∞ (Ukrainian)
# Ti·∫øng Vi·ªát (Vietnamese)
# ÁÆÄ‰Ωì‰∏≠Êñá (Chinese (Simplified))
# Ê≠£È´î‰∏≠Êñá (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn‚Äôs
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn‚Äôs
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn‚Äôs
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don‚Äôt have the app? Get it in the Microsoft Store.
# Open the app

# %%
# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nPosts\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nTrending on\nthis week\nModels\nhexgrad/Kokoro-82M\nUpdated\n1 day ago\n•\n25k\n•\n1.99k\nopenbmb/MiniCPM-o-2_6\nUpdated\nabout 1 hour ago\n•\n15k\n•\n606\nmicrosoft/phi-4\nUpdated\n11 days ago\n•\n124k\n•\n1.44k\nMiniMaxAI/MiniMax-Text-01\nUpdated\n2 days ago\n•\n2.38k\n•\n402\nNovaSky-AI/Sky-T1-32B-Preview\nUpdated\n6 days ago\n•\n7.51k\n•\n474\nBrowse 400k+ models\nSpaces\nRunning\non\nZero\n1.15k\n❤️\nKokoro TTS\nNow in 5 languages!\nRunning\non\nZero\n3.12k\n🏢\nTRELLIS\nScalable and Versatile 3D Generation from images\nRunning\n712\n🔍😊\nSearch Your Face Online\nTrack your online presence with reverse face search\nRunning\non\nZero\n1.71k\n📈\nIC Light V2\nRunning\non\nCPU Upgrade\n6.84k\n👕\nKolors Virtual Try-On\nBrowse 150k+ applications\nDatasets\nfka/awesome-chatgpt-prompts\nUpdated\n14 days ago\n•\n5.96k\n•\n6.95k\nNovaSky-AI/Sky-T1_data_17k\nUpdated\n5 days ago\n•\n1.74k\n•\n121\nHumanLLMs/Human-Like-DPO-Dataset\nUpdated\n7 days ago\n•\n914\n•\n110\nDAMO-NLP-SG/multimodal_textbook\nUpdated\n8 days ago\n•\n9.57k\n•\n115\nFreedomIntelligence/medical-o1-reasoning-SFT\nUpdated\n6 days ago\n•\n912\n•\n77\nBrowse 100k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n378 models\n•\n1.92k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.06k models\n•\n4.17k followers\nAmazon Web Services\ncompany\n•\n20 models\n•\n2.54k followers\nGoogle\ncompany\n•\n913 models\n•\n6.63k followers\nIntel\ncompany\n•\n218 models\n•\n2.15k followers\nMicrosoft\ncompany\n•\n353 models\n•\n7.46k followers\nGrammarly\ncompany\n•\n10 models\n•\n112 followers\nWriter\nEnterprise\ncompany\n•\n18 models\n•\n198 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n137,749\nState-of-the-art ML for Pytorch, TensorFlow, and JAX.\nDiffusers\n27,163\nState-of-the-art diffusion models for image and audio generation in PyTorch.\nSafetensors\n3,012\nSimple, safe way to store and distribute neural networks weights safely and quickly.\nHub Python Library\n2,235\nClient library for the HF Hub: manage repositories from your Python runtime.\nTokenizers\n9,266\nFast tokenizers, optimized for both research and production.\nPEFT\n17,008\nParameter efficient finetuning methods for large models.\nTransformers.js\n12,615\nState-of-the-art Machine Learning for the web. Run Transformers directly in your browser, with no need for a server.\ntimm\n32,928\nState-of-the-art computer vision models, layers, optimizers, training/evaluation, and utilities.\nTRL\n10,632\nTrai ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.com")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.com/about'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://huggingface.com/enterprise'}, {'type': 'blog page', 'url': 'https://huggingface.com/blog'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}]}
# # Welcome to Hugging Face: The AI Community with Hugs and Algorithms
#
# 🎉 **Join us on a journey where cuddling algorithms and machine learning meet!**
#
# ---
#
# ## What's Hugging Face?
#
# At **Hugging Face**, we like to think of ourselves as the friendly neighborhood AI community working hard to build the future (and shirtless selfies, maybe). Think of us as the Avengers of machine learning - only with less spandex and more TensorFlow! 🚀
#
# ### Our Offerings Include:
# - **400,000+ Models**: Yes, you read that right. We’re like the Netflix of machine learning models. No need to binge, just browse and deploy!
# - **100,000+ Datasets**: Because one dataset just isn't enough. A smorgasbord of data for every occasion and taste!
# - **Spaces**: Places where models come to play and collaborate—imagine a giant playground for ML nerds! 🛝
#
# ---
#
# ## Why Hugging Face?
#
# ### Community Cuddles 🤗
# Join over **50,000** organizations (yes, including **Google**, **Amazon**, and even your neighbor's cat) using our platform to share ideas, datasets, and the occasional funny meme about SQL.
#
# ### AI for Everyone
# Whether you're an **enterprise** looking for cutting-edge solutions or a budding developer trying to figure out what `pip install` means, we have something for **everyone**. Specials include dedicated support and audit logs that won’t bore you to tears!
#
# ---
#
# ## Company Culture: The Hugging Vibe
#
# At Hugging Face, we believe in:
#
# - 🚀 **Innovation**: Keep those ideas flowing like coffee at a coder's conference!
#
# - 🤝 **Collaboration**: Because what’s better than working with others? Working with friendly folks who give you positive reinforcement (not just the “great job!” kind).
#
# - 🥳 **Fun**: We take our work seriously, but we don't take ourselves seriously. In fact, if you're not for hugging, you might have your own hug-o-meter to calibrate.
#
# ---
#
# ## Careers with a Side of Giggles
#
# Are you a **coding aficionado** or a **data magician**? Inquire with us, because we’re looking for passionate individuals who can tickle our funny bone and challenge our AI!
#
# - **Current Openings**: Shuffle through our job listings, and find something that makes you say, "Wow, I can do that while also eating unicorn-shaped snacks!"
#
# - **Team Spirit**: We promise endless coffee and tea options, along with a few hugs (virtual or otherwise) from our team members.
#
# ---
#
# ## Join the Hugging Face Family Today!
#
# Whether you want to be the proud owner of an enterprise account, collaborate on the latest models, or just cultivate your passion for AI while giggling over cat memes, **Hugging Face** is your destination!
#
# ### Sign Up Now! And remember:
# **At Hugging Face, we don’t just build the future - we hug it!** 🥰
#
# ---
#
# 🤖 **Visit us at [huggingface.co](https://huggingface.co)**, where machine learning meets warm and fuzzy feelings!

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    # Jupyterde markdown için bu kod kullanılıyor
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)
        
    # for chunk in stream:
    #     print( chunk.choices[0].delta.content or '', end=" ")

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'models page', 'url': 'https://huggingface.co/models'}, {'type': 'datasets page', 'url': 'https://huggingface.co/datasets'}, {'type': 'spaces page', 'url': 'https://huggingface.co/spaces'}, {'type': 'community discussion page', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Welcome to Hugging Face - Where AI Hugs You Back!
#
# ## 🐻 What is Hugging Face, You Ask?
# Hugging Face isn't just a cute name; it's the AI community building the future! Picture a place where machine learning enthusiasts come together to collaborate on models and datasets while sharing a virtual hug or two (do not attempt this with actual bears).
#
# ## 🚀 Our Mission
# At Hugging Face, we turn “Hey, Google” moments into “Wow, that was brilliant!” experiences. If you thought only people can be creative, wait until you see our **400k+ models**! Think of us as the friendly neighborhood Spider-Man, but for AI!
#
# ## 💼 Our Customers - Who's Hugging Us Back?
# We've got more than **50,000 organizations** with a warm fuzzy feeling from collaborating with us! Giants like Meta, Amazon, Google, and Microsoft have all joined the Hugging Face fam. Yeah, no biggie... just your friendly local **AI Avengers**!
#
# ## 🌟 Company Culture
# Around here, we believe in a **collaborative approach** – because who doesn't love brainstorming while wearing their favorite sweatpants? Our culture thrives on openness, innovation, and a pinch of silliness! We might be building the future of AI, but we also know how to have fun. Expect spontaneous dance-off sessions during meetings (just kidding… or are we?).
#
# ## 🌈 Careers and Job Opportunities
# So, you're wondering what it’s like to work with us? Well, we’re on the lookout for **passionate individuals** who can hug both robots and people with equal enthusiasm. Apply today for positions in development, marketing, community management, or just about anything that makes you go “Heck yes!” Whether you’re a seasoned data scientist or a puppy-loving recruiter, we have a spot saved just for you!
#
# ## ✨ Join the Hug Life!
# Whether you're here to **check out our models**, **embed datasets** in your life, or even try our trendy **Spaces** for some 3D fun, we invite you to embrace everything about AI. No prior hugging experience necessary!
#
# ### 🖼️ Sign Up Today!
# Don’t be shy! Become a part of the community that’s shaping the future. After all, who wouldn’t want a piece of the warm, fuzzy, AI action?
#
# ## 🤖 Remember:
# **Hugging Face** - turning AI into something you can almost cuddle!
#
# ---
# *For more shenanigans, check us out at [Hugging Face](https://huggingface.co)*!

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 2 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
